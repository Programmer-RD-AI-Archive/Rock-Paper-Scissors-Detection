# %%
# !pip3 install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/ranuga/anaconda3/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: numpy~=1.19.2 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: absl-py~=0.10 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.15.6)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio~=1.32.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py~=2.10.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorboard~=2.4 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: wheel~=0.35 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: astunparse~=1.6.3 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (0.4.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.28.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/ranuga/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ranuga/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('model-1.h5')

# %%
# Create a funtion to import and image and resize it to be able to predict with our model
def load_and_prep_img(filename,img_shape=224):
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode the read file into a tensor
  img = tf.image.decode_image(img)
  # Resize the img
  img = tf.image.resize(img,[img_shape,img_shape])
  # Normalize the data
  img = img / 255.0
  return img
class_names = ['paper','rock','scissor']
def pred_and_plot(model,filename,class_names=class_names):
  """
  Imports an image located at file name and plots the image
  """
  # Import the target image and preproccess it
  img = load_and_prep_img(filename)

  # Make a pred
  pred = model.predict(tf.expand_dims(img,axis=0))

  # Get predicted class
#   pred_class = class_names[pred]
  print(pred)

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f'Preds')
  plt.axis(False);
  return pred

# %%
import numpy as np

# %%
class_names = ['paper','rock','scissor']

# %%
import os
paths = os.listdir('test data/')

# %%
paths.remove('.ipynb_checkpoints')

# %%
for path in paths:
    path = f'test data/{path}'
    img = load_and_prep_img(path)
    pred = model.predict(tf.expand_dims(img,axis=0))
    plt.figure(figsize=(5,2.5))
    plt.imshow(img)
    plt.title(f'Pred : {class_names[pred.argmax()]}')
    plt.axis(False)
    print(pred)
# Out:
# [[0.8580417  0.13532566 0.00663256]]
# [[0.9832056  0.01203459 0.00475979]]
# [[0.00333913 0.91256565 0.08409534]]
# [[0.2958158  0.00135799 0.70282626]]
# [[0.00106787 0.9908311  0.00810105]]
# [[0.922242   0.01698134 0.0607767 ]]
# [[9.5562214e-01 2.8507219e-04 4.4092782e-02]]
# [[9.99886274e-01 4.99838144e-08 1.13725975e-04]]
# [[0.00401319 0.7774908  0.218496  ]]
# [[0.00685511 0.6741929  0.31895205]]
# [[7.3829282e-04 2.6680196e-02 9.7258151e-01]]
# [[0.72469294 0.24567428 0.0296328 ]]
# [[0.00153487 0.93402576 0.06443937]]
# [[9.9999976e-01 9.0836498e-11 2.7287518e-07]]
# [[2.9641823e-04 9.7246552e-01 2.7238097e-02]]
# [[0.00141908 0.9830498  0.01553109]]
# [[0.99626875 0.00164547 0.0020858 ]]
# [[0.01433403 0.924509   0.06115697]]
# [[9.996623e-01 9.696688e-06 3.280568e-04]]
# [[4.3585875e-05 9.9208999e-01 7.8664022e-03]]
# <ipython-input-39-4393851e1aad>:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(5,2.5))
# [[9.9888653e-01 1.2689959e-07 1.1133192e-03]]
# [[9.9966252e-01 3.3690795e-04 5.5832055e-07]]
# [[0.662254   0.3036155  0.03413055]]
